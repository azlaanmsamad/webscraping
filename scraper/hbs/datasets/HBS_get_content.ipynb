# %%
import pandas as pd
import os
import glob

# %%
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
final = pd.read_csv('final_dataset/final_0.csv')
final.head()
# Out:
#    Unnamed: 0                                              Title  \
# 0           0  Why the US-China Tariff Standoff Hurts America...
# 1           1  Should US Companies Still Care About the Paris...
# 2           2                    Op-Ed: The Trouble with Tariffs
# 3           3  Op-Ed: Trump’s Tariffs Could Harm Allies as Mu...
# 4           4  How 'Teaming' Saved 33 Lives in the Chilean Mi...
#
#                                                  Url         Date  \
# 0  /item/why-the-us-china-tariff-standoff-hurts-a...  26 Jun 2019
# 1  /item/should-us-companies-still-care-about-the...  06 Sep 2018
# 2               /item/op-ed-the-trouble-with-tariffs  12 Apr 2018
# 3  /item/trump-s-tariffs-could-harm-allies-as-wel...  02 Mar 2018
# 4  /item/how-teaming-saved-33-lives-in-the-chilea...  29 Jan 2018
#
#                                              Summary          Industry
# 0  US exporters have been slashing the prices of ...  Mining and Metal
# 1  American President Donald Trump pulled out of ...  Mining and Metal
# 2  The world's economies are interconnected by gl...  Mining and Metal
# 3  President Trump's duties on steel and aluminum...  Mining and Metal
# 4  Teams composed of people from across expertise...  Mining and Metal

# %%
final.drop(columns=['Unnamed: 0'], inplace=True)
final.head()
# Out:
#                                                Title  \
# 0  Why the US-China Tariff Standoff Hurts America...
# 1  Should US Companies Still Care About the Paris...
# 2                    Op-Ed: The Trouble with Tariffs
# 3  Op-Ed: Trump’s Tariffs Could Harm Allies as Mu...
# 4  How 'Teaming' Saved 33 Lives in the Chilean Mi...
#
#                                                  Url         Date  \
# 0  /item/why-the-us-china-tariff-standoff-hurts-a...  26 Jun 2019
# 1  /item/should-us-companies-still-care-about-the...  06 Sep 2018
# 2               /item/op-ed-the-trouble-with-tariffs  12 Apr 2018
# 3  /item/trump-s-tariffs-could-harm-allies-as-wel...  02 Mar 2018
# 4  /item/how-teaming-saved-33-lives-in-the-chilea...  29 Jan 2018
#
#                                              Summary          Industry
# 0  US exporters have been slashing the prices of ...  Mining and Metal
# 1  American President Donald Trump pulled out of ...  Mining and Metal
# 2  The world's economies are interconnected by gl...  Mining and Metal
# 3  President Trump's duties on steel and aluminum...  Mining and Metal
# 4  Teams composed of people from across expertise...  Mining and Metal

# %%
final['Url'] = 'https://hbswk.hbs.edu' + final['Url']

# %%
final.head()
# Out:
#                                                Title  \
# 0  Why the US-China Tariff Standoff Hurts America...
# 1  Should US Companies Still Care About the Paris...
# 2                    Op-Ed: The Trouble with Tariffs
# 3  Op-Ed: Trump’s Tariffs Could Harm Allies as Mu...
# 4  How 'Teaming' Saved 33 Lives in the Chilean Mi...
#
#                                                  Url         Date  \
# 0  https://hbswk.hbs.edu/item/why-the-us-china-ta...  26 Jun 2019
# 1  https://hbswk.hbs.edu/item/should-us-companies...  06 Sep 2018
# 2  https://hbswk.hbs.edu/item/op-ed-the-trouble-w...  12 Apr 2018
# 3  https://hbswk.hbs.edu/item/trump-s-tariffs-cou...  02 Mar 2018
# 4  https://hbswk.hbs.edu/item/how-teaming-saved-3...  29 Jan 2018
#
#                                              Summary          Industry
# 0  US exporters have been slashing the prices of ...  Mining and Metal
# 1  American President Donald Trump pulled out of ...  Mining and Metal
# 2  The world's economies are interconnected by gl...  Mining and Metal
# 3  President Trump's duties on steel and aluminum...  Mining and Metal
# 4  Teams composed of people from across expertise...  Mining and Metal

# %%
from selenium.webdriver.chrome.options import Options
chrome_path = os.getcwd() + '/../chromedriver.exe'
chrome_options = Options()
chrome_options.add_argument('--headless')
driver = webdriver.Chrome(chrome_path, chrome_options = chrome_options)
# Out:
# /home/azlaan/.local/lib/python2.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: use options instead of chrome_options
#   """

# %%
def get_article(row):
    driver.get(row['Url'])
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    contents = soup.find_all('p', 'extra-body-padding-right')
    content = ''
    #print(contents)
    for i in contents:
        #print(i.get_text())
        #pdb.set_trace()
        content += i.get_text()
        #pdb.set_trace()
        try:
            if i.find_next_sibling().get_text() == 'About the Author':
                break
        except:
            pass
    return content

# %%
final['content'] = final.apply(get_article, axis=1)

# %%
final = pd.read_csv('final_HBS_content.csv')

# %%
final.head()
# Out:
#    Unnamed: 0                                              Title  \
# 0           0  Why the US-China Tariff Standoff Hurts America...
# 1           1  Should US Companies Still Care About the Paris...
# 2           2                    Op-Ed: The Trouble with Tariffs
# 3           3  Op-Ed: Trump’s Tariffs Could Harm Allies as Mu...
# 4           4  How 'Teaming' Saved 33 Lives in the Chilean Mi...
#
#                                                  Url         Date  \
# 0  https://hbswk.hbs.edu/item/why-the-us-china-ta...  26 Jun 2019
# 1  https://hbswk.hbs.edu/item/should-us-companies...  06 Sep 2018
# 2  https://hbswk.hbs.edu/item/op-ed-the-trouble-w...  12 Apr 2018
# 3  https://hbswk.hbs.edu/item/trump-s-tariffs-cou...  02 Mar 2018
# 4  https://hbswk.hbs.edu/item/how-teaming-saved-3...  29 Jan 2018
#
#                                              Summary          Industry  \
# 0  US exporters have been slashing the prices of ...  Mining and Metal
# 1  American President Donald Trump pulled out of ...  Mining and Metal
# 2  The world's economies are interconnected by gl...  Mining and Metal
# 3  President Trump's duties on steel and aluminum...  Mining and Metal
# 4  Teams composed of people from across expertise...  Mining and Metal
#
#                                              content
# 0  "We are the 'piggy bank' that everyone wants t...
# 1  Brian Kenny:  The April, 1938 edition of The Q...
# 2  In March, when the Trump administration releas...
# 3  After many on and off signals, President Donal...
# 4  (Editor's Note: Amy Edmondson advises managers...

# %%
final['content'][4]
# Out:
# '(Editor\'s Note: Amy Edmondson advises managers to think of teams as a verb, "teaming," which means to proactively build and develop\xc2\xa0the team even as a project is in process. Teaming, she says, is essential to organizational learning. In her new book Extreme Teaming: Lessons in Complex, Cross-Sector Leadership, Edmondson, the Novartis Professor of Leadership and Management at Harvard Business School, illustrates the advantages of teaming using a real-world example: the 2010 mine collapse in Chile that trapped 33 workers some 2,300 feet underground for 69 days.  Here\'s Emondson\'s account.)The success of the now legendary mining rescue in Chile in 2010, while widely covered in the news and immortalized in a major Hollywood \xef\xac\x81lm, is not widely understood. We offer the rescue as an extraordinary example of extreme teaming, to illustrate the enormous potential of diverse experts coming together to innovate to overcome a nearly impossible challenge. The case illustrates the centrality of diverse perspectives in producing innovation, as well as the importance of leadership in making it happen.Although mining accidents often present immense hurdles that make rescue unlikely, the situation at Chile\xe2\x80\x99s San Jose copper mine that began on August 5, 2010 was unprecedented on several dimensions. The most daunting of these was the extraordinary depth 700 meters below ground at which the miners were trapped in the aftermath of an explosion that left half a million tons of rock blocking the mine\'s entrance. The number of miners trapped (33), the hardness of the rock, the instability of the land, and the complete inadequacy of provisions for the trapped men (enough food for two men for 10 days) combined to make the possibility of rescue appear all but impossible to consulted experts. A mining rescue in the United States just a few years earlier, in which nine men were trapped 240 feet below ground, had been considered at the time a remarkable feat.In Chile, early estimates of the possibility of \xef\xac\x81nding anyone alive\xe2\x80\x94put at 10%\xe2\x80\x94diminished sharply two days later when rescue workers narrowly escaped the secondary collapse of a ventilation shaft, taking away the initial best option for extracting the miners. At that point, no expert considered rescue of the 33 men a reasonable possibility. Nonetheless, within 70 days all of them would be alive and reunited with their families.This outcome was the result of an extraordinary cross-industry teaming effort by hundreds of individuals spanning physical, organizational, cultural, geographic, and professional boundaries. Engineers, geologists, drilling specialists, and more came together from different organizations, sectors, and nations to work on the immensely challenging technical problem of locating, reaching, and extracting the trapped miners. Senior leaders in the Chilean government provided resources to support the on-site efforts.In Santiago, Chile\xe2\x80\x99s capital city, President Pi\xc3\xa6era and Laurence Golborne, the Minister of Mining, met on the morning of August 6, 2010. Pi\xc3\xa6era then sent Golborne to the mine with a mandate to do whatever possible to bring the miners home, sparing no expense. Golborne and Pi\xc3\xa6era quickly reached out to their networks of colleagues around the world. As the president put it, \xe2\x80\x9cWe were humble enough to ask for help\xe2\x80\x9d (Robbins, 2007). Michael Duncan, a deputy chief medical of\xef\xac\x81cer with the U.S. National Aeronautics and Space Administration (NASA), reported that the Chilean of\xef\xac\x81cials said, \xe2\x80\x9cLet\xe2\x80\x99s try to identify who the experts are in the \xef\xac\x81eld let\xe2\x80\x99s get some consultants in here that can give us the best information possible.\xe2\x80\x9d Duncan brought experience with long space \xef\xac\x82ights to help solve concerns related to the miners\xe2\x80\x99 physical and psychological survival in their small qu ...
