# %%
import pandas as pd

# %%
df = pd.read_csv('Agriculture_THE_SCIENTIST.csv')
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           2             2
# 3           3             3
# 4           4             4
#
#                                                Title  \
# 0  Researchers Try to Head Off “Murder Hornets” C...
# 1  Genomics Reveals How Humans Can Inadvertently ...
# 2  Variation in Cannabis Testing Challenges a You...
# 3                   Image of the Day: Dog Detectives
# 4           Infographic: Preventing a Swine Pandemic
#
#                                                  Url           Date  \
# 0  https://www.the-scientist.com/news-opinion/res...    May 4, 2020
# 1  https://www.the-scientist.com/notebook/genomic...    Mar 1, 2020
# 2  https://www.the-scientist.com/bio-business/the...    Mar 1, 2020
# 3  https://www.the-scientist.com/image-of-the-day...    Feb 5, 2020
# 4  https://www.the-scientist.com/infographics/inf...   Jan 13, 2020
#
# ...

# %%
df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'], inplace=True)

# %%
df['Summary'].nunique()
# Out:
# 179

# %%
df.shape
# Out:
# (174, 5)

# %%
df[df['Summary']==None]
# Out:
# Empty DataFrame
# Columns: [Title, Url, Date, Summary, Industry]
# Index: []

# %%
df1 = pd.read_csv('Agriculture.csv')
df1
# Out:
#     Unnamed: 0                                              Title  \
# 0            0  Silencing whistle-blowers on farms conceals an...
# 1            1  Puppies & burnout: The economic impact of the ...
# 2            2  Rethinking the boundaries between economic lif...
# 3            3  Why Ghana’s smallholders aren’t excited by the...
# 4            4  Australia’s drought relief package hits the po...
# 5            5  For a sustainable future, we need to reconnect...
# 6            6  Amazon in flames: Brazil’s Huni Kuin indigenou...
# 7            7  A sharing economy for plants: Seed libraries a...
# 8            8  How changing your diet could save animals from...
# 9            9                 Growing food in the post-truth era
# 10          10  Okja: a film that provides food for thought on...
# 11          11  The pros and cons of commercial farming models...
# 12          12  Lettuce in February: the hidden cost of buying...
# ...

# %%
df1.shape
# Out:
# (46, 6)

# %%
df2 = pd.read_csv('Agriculture_SCIENCE_NEWS.csv')
df2
# Out:
#      Unnamed: 0                                              Title  \
# 0             0  \n\t\t\t\tEngineered honeybee gut bacteria tri...
# 1             1  \n\t\t\t\tCan forensics help keep endangered r...
# 2             2  \n\t\t\t\tToo much groundwater pumping is drai...
# 3             3  \n\t\t\t\tBirds fed a common pesticide lost we...
# 4             4  \n\t\t\t\tU.S. honeybees had the worst winter ...
# 5             5  \n\t\t\t\tThe U.S. is still using many pestici...
# 6             6  \n\t\t\t\tCan Silicon Valley entrepreneurs mak...
# 7             7  \n\t\t\t\tA major crop pest can make tomato pl...
# 8             8  \n\t\t\t\tProsecco production takes a toll on ...
# 9             9  \n\t\t\t\tThis honeybee parasite may be more o...
# 10           10  \n\t\t\t\tA new way to genetically tweak photo...
# 11           11  \n\t\t\t\t50 years ago, screwworm flies inspir...
# 12           12  \n\t\t\t\tHemp fields offer a late-season poll...
# ...

# %%
df2.shape
# Out:
# (232, 6)

# %%
df2['Summary'].unique()
# Out:
# array(['\n\t\t\t\tTailored microbes defend bees with a gene-silencing process called RNA interference that takes on viruses or mites.\t\t\t',
#        '\n\t\t\t\tTimber traffickers are plundering the world\xe2\x80\x99s forests, but conservationists have a new set of tools to fight deforestation. \t\t\t',
#        '\n\t\t\t\tToo much groundwater use could push over half of pumped watersheds past an ecological tipping point by 2050, compromising aquatic ecosystems worldwide. \t\t\t',
#        '\n\t\t\t\tScientists have previously implicated neonicotinoid pesticides in declining bee populations. Now a study suggests that songbirds are affected, too.\t\t\t',
#        '\n\t\t\t\tColonies suffered from parasitic, disease-spreading Varroa mites. Floods and fire didn\xe2\x80\x99t help.\t\t\t',
#        '\n\t\t\t\tIn 2016, the United States used millions of kilograms of pesticides that are banned or being phased out in the European Union, Brazil and China. \t\t\t',
# ...

# %%
df2['Summary'].nunique()
# Out:
# 216

# %%
df2['Title'].nunique()
# Out:
# 231

# %%
final = pd.read_csv('../final_dataset/final_0.csv')
final.head()
# Out:
#    Unnamed: 0                                              Title  \
# 0           0  Why the US-China Tariff Standoff Hurts America...
# 1           1  Should US Companies Still Care About the Paris...
# 2           2                    Op-Ed: The Trouble with Tariffs
# 3           3  Op-Ed: Trump’s Tariffs Could Harm Allies as Mu...
# 4           4  How 'Teaming' Saved 33 Lives in the Chilean Mi...
#
#                                                  Url         Date  \
# 0  /item/why-the-us-china-tariff-standoff-hurts-a...  26 Jun 2019
# 1  /item/should-us-companies-still-care-about-the...  06 Sep 2018
# 2               /item/op-ed-the-trouble-with-tariffs  12 Apr 2018
# 3  /item/trump-s-tariffs-could-harm-allies-as-wel...  02 Mar 2018
# 4  /item/how-teaming-saved-33-lives-in-the-chilea...  29 Jan 2018
#
#                                              Summary          Industry
# 0  US exporters have been slashing the prices of ...  Mining and Metal
# ...

# %%
final.groupby('Industry')['Title'].count()
# Out:
# Industry
# Advertising                                        62
# Aerospace                                          13
# Agriculture and Agribusiness                       15
# Auto                                               43
# Chemical                                            6
# Computer                                           20
# Construction                                       41
# Consumer Packaged Goods                           289
# Education                                         117
# Electric Power & Natural Gas                       73
# Electronics                                        12
# Energy                                             67
# Financial Services                                384
# Health                                            178
# Manufacturing                                      75
# Mining and Metal                                    6
# Pharmaceuticals & Medical Products                 41
# ...

# %%
temp1 = pd.read_csv('Aerospace_defence_reviewdotcom.csv')

# %%
temp1.shape
# Out:
# (357, 6)

# %%
temp1['Title'][0]
# Out:
# '\n                                                QuEST Global Partners with Canon IT Solutions for Enterprise Solution...\n                                            '

# %%
temp1['Url'][0]
# Out:
# 'https://www.aerospacedefensereview.com/news/quest-global-partners-with-canon-it-solutions-for-enterprise-solution-platform-nwid-456.html'

# %%
temp1.shape
# Out:
# (357, 6)
